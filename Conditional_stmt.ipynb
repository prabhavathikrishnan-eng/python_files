# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhavathikrishnan-eng/python_files/blob/main/Conditional_stmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
y=10
if x>y:
  print(f"{x} is greater than {y}")
elif x<y:
  print(f"{x} is lesser than {y}")
else:
  print(f"{x} is equal to {y}")
# Out:
# 10 is equal to 10

# %%
def addition():
  pass
